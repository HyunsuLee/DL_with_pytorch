# %%
# %matplotlib inline
import numpy as np

# %%
from p2ch10.dsets import getCandidateInfoList, getCt, LunaDataset
candidateInfo_list = getCandidateInfoList(requireOnDisk_bool=False)
positiveInfo_list = [x for x in candidateInfo_list if x[0]]
diameter_list = [x[1] for x in positiveInfo_list]

# %%
print(len(positiveInfo_list))
print(positiveInfo_list[0])
# Out:
# 1351
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=32.27003025, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.287966244644280690737019247886', center_xyz=(75.7212243102, 92.8873310394, -119.270564052))

# %%
for i in range(0, len(diameter_list), 100):
    print('{:4}  {:4.1f} mm'.format(i, diameter_list[i]))
# Out:
#    0  32.3 mm
#  100  21.6 mm
#  200  17.3 mm
#  300  13.1 mm
#  400  10.4 mm
#  500   8.6 mm
#  600   7.4 mm
#  700   6.5 mm
#  800   6.0 mm
#  900   5.5 mm
# 1000   5.1 mm
# 1100   4.6 mm
# 1200   4.0 mm
# 1300   0.0 mm

# %%
for candidateInfo_tup in positiveInfo_list[:10]:
    print(candidateInfo_tup)
for candidateInfo_tup in positiveInfo_list[-10:]:
    print(candidateInfo_tup)
    
for candidateInfo_tup in positiveInfo_list:
    if candidateInfo_tup.series_uid.endswith('565'):
        print(candidateInfo_tup)
# Out:
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=32.27003025, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.287966244644280690737019247886', center_xyz=(75.7212243102, 92.8873310394, -119.270564052))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=32.27003025, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.287966244644280690737019247886', center_xyz=(75.2239949525, 79.4552680171, -121.430168337))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=32.27003025, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.287966244644280690737019247886', center_xyz=(70.8583605372, 73.3954511547, -104.818084289))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=32.27003025, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.287966244644280690737019247886', center_xyz=(69.4415285914, 76.6027472274, -121.084237546))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=32.27003025, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.287966244644280690737019247886', center_xyz=(67.61451718, 85.02525992, -109.8084416))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=32.27003025, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.287966244644280690737019247886', center_xyz=(66.8214732919, 81.8922059094, -121.793469669))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=32.27003025, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.287966244644280690737019247886', center_xyz=(66.1283826307, 91.4358740771, -121.999167539))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=32.27003025, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.287966244644280690737019247886', center_xyz=(64.1029275775, 84.9841485639, -95.2610904146))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=32.27003025, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.287966244644280690737019247886', center_xyz=(59.764139935, -44.678494605, -111.76505085))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=30.61040636, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.112740418331256326754121315800', center_xyz=(50.5, 27.28, -107.01))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.137763212752154081977261297097', center_xyz=(-74.74, 188.44, -468.48))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.128881800399702510818644205032', center_xyz=(-84.1, 63.4, -170.38))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.126631670596873065041988320084', center_xyz=(-102.37554865, 47.743052095, -72.28299695))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.124822907934319930841506266464', center_xyz=(30.11, -141.72, -93.49))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.112740418331256326754121315800', center_xyz=(58.2, 35.69, -102.08))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.107351566259572521472765997306', center_xyz=(123.83, -175.77, -193.99))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.107109359065300889765026303943', center_xyz=(-92.16, -78.14, -224.38))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.102681962408431413578140925249', center_xyz=(96.2846726653, 19.0348690723, -88.478440818))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.100621383016233746780170740405', center_xyz=(85.12, 152.33, -425.7))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.100621383016233746780170740405', center_xyz=(8.8, 174.74, -401.87))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=6.378436317, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.124154461048929153767743874565', center_xyz=(146.12, -160.55, -309.93))

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.hist(np.histogram(diameter_list))
# Out:
# (array([[ 3.,  3.,  2.,  0.,  0.,  1.,  0.,  0.,  0.,  1.],
#         [11.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.]]),
#  array([  0. ,  53.2, 106.4, 159.6, 212.8, 266. , 319.2, 372.4, 425.6,
#         478.8, 532. ]),
#  <a list of 2 BarContainer objects>)

# %%
from p2ch10.vis import findPositiveSamples, showCandidate
positiveSample_list = findPositiveSamples()
# Out:
# 2022-08-24 09:42:18,519 INFO     pid:283892 p2ch10.dsets:180:__init__ <p2ch10.dsets.LunaDataset object at 0x7f022d7a3d30>: 551065 training samples
# 0 CandidateInfoTuple(isNodule_bool=True, diameter_mm=32.27003025, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.287966244644280690737019247886', center_xyz=(75.7212243102, 92.8873310394, -119.270564052))
# 1 CandidateInfoTuple(isNodule_bool=True, diameter_mm=32.27003025, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.287966244644280690737019247886', center_xyz=(75.2239949525, 79.4552680171, -121.430168337))
# 2 CandidateInfoTuple(isNodule_bool=True, diameter_mm=32.27003025, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.287966244644280690737019247886', center_xyz=(70.8583605372, 73.3954511547, -104.818084289))
# 3 CandidateInfoTuple(isNodule_bool=True, diameter_mm=32.27003025, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.287966244644280690737019247886', center_xyz=(69.4415285914, 76.6027472274, -121.084237546))
# 4 CandidateInfoTuple(isNodule_bool=True, diameter_mm=32.27003025, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.287966244644280690737019247886', center_xyz=(67.61451718, 85.02525992, -109.8084416))
# 5 CandidateInfoTuple(isNodule_bool=True, diameter_mm=32.27003025, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.287966244644280690737019247886', center_xyz=(66.8214732919, 81.8922059094, -121.793469669))
# 6 CandidateInfoTuple(isNodule_bool=True, diameter_mm=32.27003025, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.287966244644280690737019247886', center_xyz=
series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.121391737347333465796214915391', center_xyz=(51.27, -67.3, -117.57))
# 84 CandidateInfoTuple(isNodule_bool=True, diameter_mm=22.13322034, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.121391737347333465796214915391', center_xyz=(47.06, -56.08, -122.49))
# 85 CandidateInfoTuple(isNodule_bool=True, diameter_mm=22.13322034, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.121391737347333465796214915391', center_xyz=(46.423809125, -64.87603544, -122.4506795))
# 86 CandidateInfoTuple(isNodule_bool=True, diameter_mm=22.03891888, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.272344603176687884771013620823', center_xyz=(97.5068670021, 10.1024122586, -117.638060442))
# 87 CandidateInfoTuple(isNodule_bool=True, diameter_mm=22.03891888, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.272344603176687884771013620823', center_xyz=(96.97240574, 1.775612227, -113.0049791))
# 88 CandidateInfoTuple(isNodule_bool=True, diameter_mm=22.03891888, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.272344603176687884771013620823', center_xyz=(95.62, -4.54, -111.89))
# 89 CandidateInfoTuple(isNodule_bool=True, diameter_mm=21.87973183, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.625270601160880745954773142570', center_xyz=(-108.2007072, 46.48017452, -143.2481594))
# 90 CandidateInfoTuple(isNodule_bool=True, diameter_mm=21.87973183, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.625270601160880745954773142570', center_xyz=(-109.95, 40.62, -145.83))
# 91 CandidateInfoTuple(isNodule_bool=True, diameter_mm=21.82795321, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.123697637451437522065941162930', center_xyz=(-128.341115395, -14.2479988938, -77.7156132477))
# 92 CandidateInfoTuple(isNodule_bool=True, diameter_mm=21.67749437, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.306948744223170422945185006551', center_xyz=(116.96, 6.9, -213.97))
# 93 CandidateInfoTuple(isNodule_bool=True, diameter_mm=21.67749437, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.306948744223170422945185006551', center_xyz=(116.230456408, -5.41706858615, -216.13106459))
# 94 CandidateInfoTuple(isNodule_bool=True, diameter_mm=21.67749437, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.306948744223170422945185006551', center_xyz=(115.8300923, -1.798282385, -208.7569347))
# 95 CandidateInfoTuple(isNodule_bool=True, diameter_mm=21.67749437, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.306948744223170422945185006551', center_xyz=(113.573664327, 2.78517529295, -199.9979832))
# 96 CandidateInfoTuple(isNodule_bool=True, diameter_mm=21.58311204, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.905371958588660410240398317235', center_xyz=(110.83, 57.69, -122.43))
# 97 CandidateInfoTuple(isNodule_bool=True, diameter_mm=21.58311204, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.905371958588660410240398317235', center_xyz=(109.142472723, 49.6356928166, -121.183579092))
# 98 CandidateInfoTuple(isNodule_bool=True, diameter_mm=21.57854728, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.624425075947752229712087113746', center_xyz=(-72.25, -52.22, -264.5))
# 99 CandidateInfoTuple(isNodule_bool=True, diameter_mm=21.57854728, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.624425075947752229712087113746', center_xyz=(-72.66975017, -60.94410393, -262.0051515))

# %%
series_uid = positiveSample_list[11][2]
showCandidate(series_uid)
# Out:
# 2022-08-24 09:44:23,059 INFO     pid:283892 p2ch10.dsets:180:__init__ <p2ch10.dsets.LunaDataset object at 0x7f01ac8b95e0>: 911 training samples
# 1.3.6.1.4.1.14519.5.2.1.6279.6001.112740418331256326754121315800 0 False [0, 1, 2, 3, 4, 5, 6]

# %%
series_uid = '1.3.6.1.4.1.14519.5.2.1.6279.6001.124154461048929153767743874565'
showCandidate(series_uid)
# Out:
# 2022-08-24 09:42:20,324 INFO     pid:283892 p2ch10.dsets:180:__init__ <p2ch10.dsets.LunaDataset object at 0x7f01a0d940a0>: 1061 training samples
# <div id='0e05eac2-40d0-4557-afef-360bf8e5850a'></div>
# 1.3.6.1.4.1.14519.5.2.1.6279.6001.124154461048929153767743874565 0 False [0]

# %%
series_uid = '1.3.6.1.4.1.14519.5.2.1.6279.6001.126264578931778258890371755354'
showCandidate(series_uid)
# Out:
# 2022-08-24 09:42:21,832 INFO     pid:283892 p2ch10.dsets:180:__init__ <p2ch10.dsets.LunaDataset object at 0x7f01c219fdf0>: 605 training samples
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /home/hyunsu/Documents/GitHub/DL_with_pytorch/p2ch10_explore_data.ipynb Cell 10 in <cell line: 2>()
#       <a href='vscode-notebook-cell://ssh-remote%2Bubuntu223/home/hyunsu/Documents/GitHub/DL_with_pytorch/p2ch10_explore_data.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> series_uid = '1.3.6.1.4.1.14519.5.2.1.6279.6001.126264578931778258890371755354'
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bubuntu223/home/hyunsu/Documents/GitHub/DL_with_pytorch/p2ch10_explore_data.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> showCandidate(series_uid)
#
# File ~/Documents/GitHub/DL_with_pytorch/p2ch10/vis.py:37, in showCandidate(series_uid, batch_ndx, **kwargs)
#      34         batch_ndx = 0
#      36 ct = Ct(series_uid)
# ---> 37 ct_t, pos_t, series_uid, center_irc = ds[batch_ndx]
#      39 ct_a = ct_t[0].numpy()
#      40 ct_a = ct_a[0,:,:,:]
#
# File ~/Documents/GitHub/DL_with_pytorch/p2ch10/dsets.py:200, in LunaDataset.__getitem__(self, ndx)
#     197 candidateInfo_tup = self.candidateInfo_list[ndx]
#     198 width_irc = (32, 48, 48)
# --> 200 candidate_a, center_irc = getCtRawCandidate( # here tuple sample generated
#     201     candidateInfo_tup.series_uid,
#     202     candidateInfo_tup.center_xyz,
#     203     width_irc,
#     204 )
#     206 candidate_t = torch.from_numpy(candidate_a)
#     207 candidate_t = candidate_t.to(torch.float32)
#
# File ~/anaconda3/envs/th1p12/lib/python3.8/site-packages/diskcache/core.py:1888, in Cache.memoize.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#    1885 result = self.get(key, default=ENOVAL, retry=True)
#    1887 if result is ENOVAL:
# -> 1888     result = func(*args, **kwargs)
#    1889     if expire is None or expire > 0:
#    1890         self.set(key, result, expire, tag=tag, retry=True)
#
# File ~/Documents/GitHub/DL_with_pytorch/p2ch10/dsets.py:155, in getCtRawCandidate(series_uid, center_xyz, width_irc)
#     152 @raw_cache.memoize(typed=True)
#     153 def getCtRawCandidate(series_uid, center_xyz, width_irc):
#     154     ct = getCt(series_uid)
# --> 155     ct_chunk, center_irc = ct.getRawCandidate(center_xyz, width_irc)
#     156     return ct_chunk, center_irc
#
# File ~/Documents/GitHub/DL_with_pytorch/p2ch10/dsets.py:127, in Ct.getRawCandidate(self, center_xyz, width_irc)
#     124 start_ndx = int(round(center_val - width_irc[axis]/2))
#     125 end_ndx = int(start_ndx + width_irc[axis])
# --> 127 assert center_val >= 0 and center_val < self.hu_a.shape[axis], repr([self.series_uid, center_xyz, self.origin_xyz, self.vxSize_xyz, center_irc, axis])
#     129 if start_ndx < 0:
#     130     # log.warning("Crop outside of CT array: {} {}, center:{} shape:{} width:{}".format(
#     131     #     self.series_uid, center_xyz, center_irc, self.hu_a.shape, width_irc))
#     132     start_ndx = 0
#
# AssertionError: ['1.3.6.1.4.1.14519.5.2.1.6279.6001.126264578931778258890371755354', (59.73, -157.0, -119.49), XyzTuple(x=-163.1962890625, y=-319.1962890625, z=-380.5), XyzTuple(x=0.607421875, y=0.607421875, z=0.5), IrcTuple(index=522, row=267, col=367), 0]

# %%
LunaDataset()[0]
# Out:
# 2022-08-24 09:42:41,789 INFO     pid:283892 p2ch10.dsets:180:__init__ <p2ch10.dsets.LunaDataset object at 0x7f01ad4746d0>: 551065 training samples
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /home/hyunsu/Documents/GitHub/DL_with_pytorch/p2ch10_explore_data.ipynb Cell 11 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bubuntu223/home/hyunsu/Documents/GitHub/DL_with_pytorch/p2ch10_explore_data.ipynb#X13sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> LunaDataset()[0]
#
# File ~/Documents/GitHub/DL_with_pytorch/p2ch10/dsets.py:200, in LunaDataset.__getitem__(self, ndx)
#     197 candidateInfo_tup = self.candidateInfo_list[ndx]
#     198 width_irc = (32, 48, 48)
# --> 200 candidate_a, center_irc = getCtRawCandidate( # here tuple sample generated
#     201     candidateInfo_tup.series_uid,
#     202     candidateInfo_tup.center_xyz,
#     203     width_irc,
#     204 )
#     206 candidate_t = torch.from_numpy(candidate_a)
#     207 candidate_t = candidate_t.to(torch.float32)
#
# File ~/anaconda3/envs/th1p12/lib/python3.8/site-packages/diskcache/core.py:1888, in Cache.memoize.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#    1885 result = self.get(key, default=ENOVAL, retry=True)
#    1887 if result is ENOVAL:
# -> 1888     result = func(*args, **kwargs)
#    1889     if expire is None or expire > 0:
#    1890         self.set(key, result, expire, tag=tag, retry=True)
#
# File ~/Documents/GitHub/DL_with_pytorch/p2ch10/dsets.py:155, in getCtRawCandidate(series_uid, center_xyz, width_irc)
#     152 @raw_cache.memoize(typed=True)
#     153 def getCtRawCandidate(series_uid, center_xyz, width_irc):
#     154     ct = getCt(series_uid)
# --> 155     ct_chunk, center_irc = ct.getRawCandidate(center_xyz, width_irc)
#     156     return ct_chunk, center_irc
#
# File ~/Documents/GitHub/DL_with_pytorch/p2ch10/dsets.py:127, in Ct.getRawCandidate(self, center_xyz, width_irc)
#     124 start_ndx = int(round(center_val - width_irc[axis]/2))
#     125 end_ndx = int(start_ndx + width_irc[axis])
# --> 127 assert center_val >= 0 and center_val < self.hu_a.shape[axis], repr([self.series_uid, center_xyz, self.origin_xyz, self.vxSize_xyz, center_irc, axis])
#     129 if start_ndx < 0:
#     130     # log.warning("Crop outside of CT array: {} {}, center:{} shape:{} width:{}".format(
#     131     #     self.series_uid, center_xyz, center_irc, self.hu_a.shape, width_irc))
#     132     start_ndx = 0
#
# AssertionError: ['1.3.6.1.4.1.14519.5.2.1.6279.6001.287966244644280690737019247886', (75.7212243102, 92.8873310394, -119.270564052), XyzTuple(x=-212.199997, y=-210.0, z=-338.0), XyzTuple(x=0.8203120231628418, y=0.8203120231628418, z=2.5), IrcTuple(index=87, row=369, col=351), 0]

# %% [markdown]
# # Note: the following visualization doesn't look very good.
# It's only included here for completeness.

# %%
import scipy.ndimage.morphology
def build2dLungMask(ct, mask_ndx, threshold_gcc = 0.7):
    dense_mask = ct.hu_a[mask_ndx] > threshold_gcc
    denoise_mask = scipy.ndimage.morphology.binary_closing(dense_mask, iterations=2)
    tissue_mask = scipy.ndimage.morphology.binary_opening(denoise_mask, iterations=10)
    body_mask = scipy.ndimage.morphology.binary_fill_holes(tissue_mask)
    air_mask = scipy.ndimage.morphology.binary_fill_holes(body_mask & ~tissue_mask)

    lung_mask = scipy.ndimage.morphology.binary_dilation(air_mask, iterations=2)

    return air_mask, lung_mask, dense_mask, denoise_mask, tissue_mask, body_mask


def build3dLungMask(ct):
    air_mask, lung_mask, dense_mask, denoise_mask, tissue_mask, body_mask = mask_list = \
        [np.zeros_like(ct.hu_a, dtype=np.bool) for _ in range(6)]

    for mask_ndx in range(ct.hu_a.shape[0]):
        for i, mask_ary in enumerate(build2dLungMask(ct, mask_ndx)):
            mask_list[i][mask_ndx] = mask_ary

    return air_mask, lung_mask, dense_mask, denoise_mask, tissue_mask, body_mask

# %%
from p2ch10.dsets import getCt
ct = getCt(series_uid)
air_mask, lung_mask, dense_mask, denoise_mask, tissue_mask, body_mask = build3dLungMask(ct)
# Out:
# /tmp/ipykernel_283892/2460116618.py:16: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   [np.zeros_like(ct.hu_a, dtype=np.bool) for _ in range(6)]
# /tmp/ipykernel_283892/2460116618.py:4: DeprecationWarning: Please use `binary_closing` from the `scipy.ndimage` namespace, the `scipy.ndimage.morphology` namespace is deprecated.
#   denoise_mask = scipy.ndimage.morphology.binary_closing(dense_mask, iterations=2)
# /tmp/ipykernel_283892/2460116618.py:5: DeprecationWarning: Please use `binary_opening` from the `scipy.ndimage` namespace, the `scipy.ndimage.morphology` namespace is deprecated.
#   tissue_mask = scipy.ndimage.morphology.binary_opening(denoise_mask, iterations=10)
# /tmp/ipykernel_283892/2460116618.py:6: DeprecationWarning: Please use `binary_fill_holes` from the `scipy.ndimage` namespace, the `scipy.ndimage.morphology` namespace is deprecated.
#   body_mask = scipy.ndimage.morphology.binary_fill_holes(tissue_mask)
# /tmp/ipykernel_283892/2460116618.py:7: DeprecationWarning: Please use `binary_fill_holes` from the `scipy.ndimage` namespace, the `scipy.ndimage.morphology` namespace is deprecated.
#   air_mask = scipy.ndimage.morphology.binary_fill_holes(body_mask & ~tissue_mask)
# /tmp/ipykernel_283892/2460116618.py:9: DeprecationWarning: Please use `binary_dilation` from the `scipy.ndimage` namespace, the `scipy.ndimage.morphology` namespace is deprecated.
#   lung_mask = scipy.ndimage.morphology.binary_dilation(air_mask, iterations=2)
